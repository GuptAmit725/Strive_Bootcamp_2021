# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

data = pd.read_csv(url)
data.head()

plt.figure(figsize=(15,10))
plt.xlabel('Month Number')
plt.ylabel('Total profit')
plt.plot(data['month_number'],data['total_profit'])
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 2: Get the Total profit of all months and show a line plot with the following Style properties:
# - Line Style dotted and Line color should be red
# - Show legend at the lower right location.
# - X label name = Month Number
# - Y label name = Sold units number
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

plt.figure(figsize=(15,10))
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.plot(data['month_number'],data['total_profit'],linewidth=3,linestyle='--',marker='o',color='red')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
data.shape
# Out:
# (12, 9)

# %%
data.columns[1:len(data.columns)-2]
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))

#plt.figure(figsize=(15,10))
#ax.xlabel('Month Number')
#ax.ylabel('Sold units number')
for col in data.columns[1:len(data.columns)-2]:
  ax.plot(data['month_number'],data[col],linewidth=3,marker='o')
ax.legend(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
       'moisturizer'])  
ax.grid(True)

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.figure(figsize=(15,10))
plt.scatter(data['month_number'],data['toothpaste'], marker = 'o', s = 200,color='blue')
plt.title('Toothpaste Sales Data',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('Number of units sold',fontsize=20)
plt.grid(True,linestyle='--', linewidth = 3)
plt.show()

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(9,6))
plt.title('Facewash and Facecream Sales Data',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('sales units in number', fontsize=20)

plt.bar(data['month_number'],data['facecream'],width = 0.2)
plt.bar(data['month_number'],data['facewash'],width = 0.2)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Write your code here

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(9,6))
plt.title('Bathing soap Sales Data',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('sales units in number', fontsize=20)

plt.bar(data['month_number'],data['bathingsoap'])
#plt.bar(data['month_number'],data['facewash'],width = 0.2)
plt.grid(True,linestyle='--',linewidth =2)
plt.tight_layout()
plt.show()

# %%
# Write your code here

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
plt.figure(figsize=(10,8))
plt.title('Profit Data',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('Actual profit in Dollars', fontsize=20)
sns.histplot(data['total_profit'])
plt.show()

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(2, 1, 1) # 2 rows, 2 cols, first element
ax.plot(data['month_number'],data['bathingsoap'],marker='o', linewidth=3, color='black')
ax = fig.add_subplot(2, 1, 2) # 2 rows, 2 cols, last element
ax.plot(data['month_number'],data['facewash'],marker='o', linewidth=3, color='red')
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
plt.figure(figsize=(10,8))
plt.title('All product sales',fontsize=20)
plt.xlabel('Month Number',fontsize=20)
plt.ylabel('Total Sales', fontsize=20)
plt.stackplot(data['facecream'],data['facewash'],data['toothpaste'],data['bathingsoap'],data['shampoo'],data['moisturizer'] )
plt.legend(['facecream','facewash','toothpaste','bathinsoap','shampoo','shampoo','moisturizer'],loc='upper left')
plt.show()

# %%
# Write your code here
